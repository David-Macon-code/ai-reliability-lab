# %% [markdown]
# # Amazon Bedrock Knowledge Bases Tasks Setup
# ---
#
# ## Prerequisites
#
# Run the cells in this section to install the packages needed by the notebooks. ⚠️ You will see pip dependency errors, you can safely ignore these errors. ⚠️
#
# IGNORE ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.

# %%
# %pip uninstall -y boto3 opensearch-py botocore awscli langchain langchain-core langchain-community langchain-text-splitters langchain-aws retrying ragas ipywidgets iprogress openpyxl pydantic
# %pip install boto3
# %pip install opensearch-py
# %pip install botocore
# %pip install awscli
# %pip install "langchain>=0.3,<0.4"
# %pip install "langchain-core>=0.3,<0.4"
# %pip install "langchain-community>=0.3,<0.4"
# %pip install "langchain-text-splitters>=0.3,<0.4"
# %pip install "langchain-aws>=0.2,<0.3"
# %pip install retrying
# %pip install ragas==0.1.16
# %pip install ipywidgets
# %pip install iprogress
# %pip install openpyxl
# %pip install "pydantic>=2,<3"
# Out:
# Found existing installation: boto3 1.42.73
# Uninstalling boto3-1.42.73:
#   Successfully uninstalled boto3-1.42.73
# Found existing installation: botocore 1.42.73
# Uninstalling botocore-1.42.73:
#   Successfully uninstalled botocore-1.42.73
# Found existing installation: awscli 1.44.63
# Uninstalling awscli-1.44.63:
#   Successfully uninstalled awscli-1.44.63
# Found existing installation: langchain 0.3.28
# Uninstalling langchain-0.3.28:
#   Successfully uninstalled langchain-0.3.28
# Found existing installation: langchain-core 0.3.83
# Uninstalling langchain-core-0.3.83:
#   Successfully uninstalled langchain-core-0.3.83
# Found existing installation: langchain-community 0.3.31
# Uninstalling langchain-community-0.3.31:
#   Successfully uninstalled langchain-community-0.3.31
# Found existing installation: langchain-text-splitters 0.3.11
# Uninstalling langchain-text-splitters-0.3.11:
#   Successfully uninstalled langchain-text-splitters-0.3.11
# Found existing installation: langchain-aws 0.2.35
# Uninstalling langchain-aws-0.2.35:
#   Successfully uninstalled langchain-aws-0.2.35
# Found existing installation: pydantic 2.12.5
# Uninstalling pydantic-2.12.5:
#   Successfully uninstalled pydantic-2.12.5
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~qlalchemy (C:\Users\macon\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages)
# WARNING: Skipping opensearch-py as it is not installed.
# WARNING: Ignoring invalid distribution ~qlalchemy (C:\Users\macon\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages)
# WARNING: Skipping retrying as it is not installed.
# WARNING: Ignoring invalid distribution ~qlalchemy (C:\Users\macon\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages)
# WARNING: Skipping ragas as it is not installed.
# WARNING: Ignoring invalid distribution ~qlalchemy (C:\Users\macon\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages)
# WARNING: Skipping ipywidgets as it is not installed.
# WARNING: Ignoring invalid distribution ~qlalchemy (C:\Users\macon\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages)
# WARNING: Skipping iprogress as it is not installed.
# WARNING: Ignoring invalid distribution ~qlalchemy (C:\Users\macon\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages)
# WARNING: Skipping openpyxl as it is not installed.
# Collecting boto3
#   Using cached boto3-1.42.73-py3-none-any.whl.metadata (6.7 kB)
# Collecting botocore<1.43.0,>=1.42.73 (from boto3)
#   Using cached botocore-1.42.73-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in C:\Users\macon\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from boto3) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in C:\Users\macon\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from boto3) (0.16.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in C:\Users\macon\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from botocore<1.43.0,>=1.42.73->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in C:\Users\macon\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from botocore<1.43.0,>=1.42.73->boto3) (2.6.3)
# Requirement already satisfied: six>=1.5 in C:\Users\macon\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.43.0,>=1.42.73->boto3) (1.17.0)
# Using cached boto3-1.42.73-py3-none-any.whl (140 kB)
# Using cached botocore-1.42.73-py3-none-any.whl (14.7 MB)
# Installing collected packages: botocore, boto3
#
#    ---------------------------------------- 0/2 [botocore]
#    ---------------------------------------- 0/2 [botocore]
#    ---------------------------------------- 0/2 [botocore]
#    ---------------------------------------- 0/2 [botocore]
#    ---------------------------------------- 0/2 [botocore]
#    ---------------------------------------- 0/2 [botocore]
#    ---------------------------------------- 0/2 [botocore]
#    ---------------------------------------- 0/2 [botocore]
#    ---------------------------------------- 0/2 [botocore]
#    ---------------------------------------- 0/2 [botocore]
#    ---------------------------------------- 0/2 [botocore]
#    ---------------------------------------- 0/2 [botocore]
#    ---------------------------------------- 0/2 [botocore]
#    ---------------------------------------- 0/2 [botocore]
#    ---------------------------------------- 0/2 [botocore]
#    ---------------------------------------- 0/2 [botocore]
#    ---------------------------------------- 0/2 [botocore]
#    ---------------------------------------- 0/2 [botocore]
#    ---------------------------------------- 0/2 [botocore]
#    ---------------------------------------- 0/2 [botocore]
#    ---------------------------------------- 0/2 [botocore]
#    ---------------------------------------- 0/2 [botocore]
#    ---------------------------------------- 0/2 [botocore]
#    ---------------------------------------- 0/2 [botocore]
#    ---------------------------------------- 0/2 [botocore]
#    ---------------------------------------- 0/2 [botocore]
#    ---------------------------------------- 0/2 [botocore]
#    -------------------- ------------------- 1/2 [boto3]
#    -------------------- ------------------- 1/2 [boto3]
#    -------------------- ------------------- 1/2 [boto3]
#    -------------------- ------------------- 1/2 [boto3]
#    ---------------------------------------- 2/2 [boto3]
#
# Successfully installed boto3-1.42.73 botocore-1.42.73
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~qlalchemy (C:\Users\macon\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~qlalchemy (C:\Users\macon\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~qlalchemy (C:\Users\macon\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages)

# %% [markdown]
# ### Restart the kernel after running the above cell
