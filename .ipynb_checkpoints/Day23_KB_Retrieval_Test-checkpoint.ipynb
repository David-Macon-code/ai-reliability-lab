# %%
import boto3
import json

bedrock_agent = boto3.client('bedrock-agent-runtime', region_name='us-east-1')

KB_ID = "8OOQBDOPXT"
MODEL_ID = "anthropic.claude-sonnet-4-5-20250929-v1:0"  # try Sonnet first

query = "Where does John Doe live and what does he do?"

response = bedrock_agent.retrieve_and_generate(
    input={"text": query},
    retrieveAndGenerateConfiguration={
        "type": "KNOWLEDGE_BASE",
        "knowledgeBaseConfiguration": {
            "knowledgeBaseId": KB_ID,
            "modelArn": f"arn:aws:bedrock:us-east-1::foundation-model/{MODEL_ID}",
            "retrievalConfiguration": {
                "vectorSearchConfiguration": {
                    "numberOfResults": 3
                }
            }
        }
    }
)

print("=== Retrieved Chunks ===")
citations = response.get('citations', [])
if citations and len(citations) > 0:
    retrieved_refs = citations[0].get('retrievedReferences', [])
    if retrieved_refs:
        for chunk in retrieved_refs:
            text = chunk.get('content', {}).get('text', 'No content')
            print("- " + text[:200] + "...\n")
    else:
        print("(No retrieved references cited)")
else:
    print("(No citations returned — model answered directly)")

print("\n=== Generated Answer ===")
print(response['output']['text'])
